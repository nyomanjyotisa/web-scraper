# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
import pandas as pd
from difflib import SequenceMatcher

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="",
  database="sern2389_chord-gitar"
)
cur_mydb = mydb.cursor()

query = "SELECT * FROM wp_posts"
cur_mydb.execute(query)
testt = cur_mydb.fetchall()

for tesaja in testt:
    query = "SELECT * FROM wp_posts"
    cur_mydb.execute(query)
    testsatu = cur_mydb.fetchall()
    print("   "+tesaja[5])
    for testtsatu in testsatu:
        if testtsatu[0]!=tesaja[0]:
            judulcek = SequenceMatcher(None, testtsatu[5], tesaja[5]).ratio()
            if judulcek>0.7:
                print(judulcek)
                print(testtsatu[5])
                print(SequenceMatcher(None, testtsatu[4], tesaja[4]).ratio())
# Out:
#    Nanoe Biroe - Matan Iluhe Mobil
# 0.9523809523809523
# Nanoe Biroe - Matan I Luhe Mobil
# 0.03640375068946498
#    Ary Kencana - Baper
# 1.0
# Ary Kencana - Baper
# 0.12244897959183673
# 0.7441860465116279
# Ary Kencana - Biro Jodoh
# 0.018537590113285273
# 0.7272727272727273
# Ary Kencana - Putih Bagus
# 0.022116903633491312
# 0.7391304347826086
# Ary Kencana - Kutang Rerama
# 0.018243419338024498
#    Kis Band - Fullmoon
# 0.7428571428571429
# Kis Band - Malam
# 0.040392383150605886
# 0.7272727272727273
# Chord KIS Band - FullMoon
# 0.6903803131991052
#    Leeyonk Sinatra - LDR (Lelah Dilanda Rindu)
# 0.925
# Leeyonk Sinatra - Lelah Dilanda Rindu
# 0.0911032028469751
# 0.8837209302325582
# Leeyonk Sinatra - Lelah Dilanda Rindu (LDR)
# 0.11650485436893204
#    Harmonia - Lagu Untukmu
# 0.72
# Frengky Zega - Lagu Untukmu
# 0.016618497109826588
# 0.7346938775510204
# Harmonia - Lampaui Batasmu
# 0.01804757998359311
# 0.7058823529411765
# Jhoni Smokers - Lagu Untukmu
# 0.016549968173138127
# 0.8372093023255814
# Raisa - Lagu Untukmu
# 0.005706562546928968
# 0.7083333333333334
# Stela Band - Lagu Untukmu
# 0.006052581804425951
# 0.7272727272727273
# Dr. PM - Lagu Untukmu
# 0.010345942450695119
# 0.7111111111111111
# Anima - Selalu Untukmu
# 0.01491681009753299
#    Nol Dp - Putu Sintya Dewi
#    Bintang Band - Satya
# 0.7906976744186046
# Bintang Band - Bidadari
# 0.045440589499539455
# 0.7083333333333334
# Bintang Band - Manis Manesin
# 0.047530864197530866
# 0.8571428571428571
# Bintang - Satya
# 0.48431155407899595
# 0.7272727272727273
# Bintang Band - Melepasmu
# 0.020213687554143805
# 0.85
# Bintang Band - Hampa
# 0.02238567316917173
#    Motifora - Hitam Putih
# 0.7317073170731707
# Sonia - Cinta Putih
# 0.004805766920304365
#    Lolot - Ulian Punyah
# 0.8235294117647058
# Lolot - Punyah
# 0.04295942720763723
#    Yoganata - Ade Ne Kuang
#    Nanoe Biroe - Merasa Coklat
# 0.009161381254404511
# 0.7547169811320755
# Di Ubud Band - Bulan Bintang
# 0.02470623681831877
#    4WD - Persimpangan Hati
# 0.7317073170731707
# 4WD - Curahan Hati
# 0.03495145631067961
# 0.723404255319149
# LYON - Persimpangan Lara
# 0.013380909901873328
# 0.7017543859649122
# Olivia Gunawan - Persimpangan Hati
# 0.008495416946121171
#    BNSP - Punyah
#    Rocktober - Tolong Jujur Ken Beli
#    Bayu Cuaca - Ngeling Sambil Manting
#    Lolot - Karman Beli
# 0.717948717948718
# Lolot - Tembang Balu
# 0.04346673734428837
# 0.7428571428571429
# Lolot - Kasmaran
# 0.03910754575081474
# 0.7027027027027027
# Lolot - Putri Bali
# 0.012726382770435633
#    Lolot - Tembang Balu
# 0.717948717948718
# Lolot - Karman Beli
# 0.04028624436787702
# 0.8780487804878049
# Lolot - Tembang Jaruh
# 0.014606741573033709
# 0.75
# Lolot - Jelema Palsu
# 0.012987012987012988
# 0.717948717948718
# Kotak - Teman Palsu
# 0.013744075829383886
#    Lolot - Nyujuh Langit
#    Sunset Band - Sing Ngidang Ngomong Ape
#    Raja Band - Iluh Aluh
# 0.7441860465116279
# Raja Band - Pelih Beli
# 0.050928699820251645
#    Lolot - Swasti Wanti Warsa
#    Lolot - Beli Naskeleng
#    Bintang Band - Manis Manesin
# 0.7083333333333334
# Bintang Band - Satya
# 0.02345679012345679
# 0.7058823529411765
# Bintang Band - Bidadari
# 0.06324972737186478
# 0.9019607843137255
# Bintang - Manis Manesin
# 0.2260424286759327
# 0.7083333333333334
# Bintang Band - Hampa
# 0.007630675314765357
#    Mercy - Api Cemburu
# 0.7058823529411765
# After - Cemburu
# 0.011534025374855825
#    Lolot - Astungkara
# 0.7058823529411765
# Lolot - Kasmaran
# 0.008461131676361713
# 0.7222222222222222
# Lolot - Pesta Pora
# 0.010948905109489052
#    NorthSideBoys12 - Rasa Bangga (Bali United Anthem)
#    Lolot - Masawitra
# 0.7878787878787878
# Lolot - Kasmaran
# 0.02403268445085316
# 0.8
# Lolot - Maplesiran
# 0.011085450346420323
#    Made Band - Sejujurnya
# 0.7111111111111111
# Pas Band - Sesungguhnya
# 0.012838801711840228
# 0.7111111111111111
# Aswar Toya - Sejujurnya
# 0.0060721062618595825
#    Rocktober - R.I.P
# 0.7567567567567568
# Rocktober - Rasa Ini
# 0.008275862068965517
#    XXX Band - Nu Kangen
# 0.7368421052631579
# Biru Band - Kangen
# 0.0235467255334805
#    Tiari Bintang - Swalapatresna
# 0.8529411764705882
# Lolot ft. Tiari Bintang - Swalapatresna
# 0.03489071586123922
#    Bayu Cuaca - Tunangan Langka
# 1.0
# Bayu Cuaca - Tunangan Langka
# 0.23248769405528208
#    703 Band - Tulus Tersakiti
# 0.9122807017543859
# 703 Band Bali - Tulus Tersakiti
# 0.9003606853020739
#    703 Band Bali - Tulus Tersakiti
#    Rajapala Band - Angin Malam
# 0.723404255319149
# Sahara - Angin Malam
# 0.01581410359851541
#    Sri Aditya - Belog Megandong
#    Ray Peni - Gelas di lemari
#    Kis Band - Sakit Jiwa
# 0.7567567567567568
# Kis Band - Sabar
# 0.02470895699691138
# 0.7027027027027027
# Kis Band - Malam
# 0.05268292682926829
# 0.75
# Kis Band - Main Api
# 0.016731734523145567
#    Raja Band - Pelih Beli
# 0.7441860465116279
# Raja Band - Iluh Aluh
# 0.052726183343319355
#    Lolot - Bajang Cerik Tusing Perawan
#    Bintang Band - Sayonara Mata Aimashou
#    Nanoe Biroe - Balik Yuk Balik
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-268c2da1c467> in <module>
#      20 for tesaja in testt:
#      21     query = "SELECT * FROM wp_posts"
# ---> 22     cur_mydb.execute(query)
#      23     testsatu = cur_mydb.fetchall()
#      24     print("   "+tesaja[5])
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\connections.py in read(self)
#    1074                 self._read_load_local_packet(first_packet)
#    1075             else:
# -> 1076                 self._read_result_packet(first_packet)
#    1077         finally:
#    1078             self.connection = None
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\connections.py in _read_result_packet(self, first_packet)
#    1144         self.field_count = first_packet.read_length_encoded_integer()
#    1145         self._get_descriptions()
# -> 1146         self._read_rowdata_packet()
#    1147
#    1148     def _read_rowdata_packet_unbuffered(self):
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\connections.py in _read_rowdata_packet(self)
#    1178         rows = []
#    1179         while True:
# -> 1180             packet = self.connection._read_packet()
#    1181             if self._check_packet_is_eof(packet):
#    1182                 self.connection = None  # release reference to kill cyclic reference.
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     661             self._next_seq_id = (self._next_seq_id + 1) % 256
#     662
# --> 663             recv_data = self._read_bytes(bytes_to_read)
#     664             if DEBUG: dump_packet(recv_data)
#     665             buff += recv_data
#
# ~\anaconda3\envs\jyotisa-gpu\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     678
#     679     def _read_bytes(self, num_bytes):
# --> 680         self._sock.settimeout(self._read_timeout)
#     681         while True:
#     682             try:
#
# KeyboardInterrupt:
