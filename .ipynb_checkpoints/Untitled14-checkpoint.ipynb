# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
import pandas as pd
from difflib import SequenceMatcher

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="",
  database="sern2389_chord-gitar"
)
cur_mydb = mydb.cursor()

query = "SELECT * FROM wp_posts"
cur_mydb.execute(query)
testt = cur_mydb.fetchall()

for tesaja in testt:
    query = "SELECT * FROM wp_posts"
    cur_mydb.execute(query)
    testsatu = cur_mydb.fetchall()
    print("   "+tesaja[5])
    for testtsatu in testsatu:
        if testtsatu[0]!=tesaja[0]:
            judulcek = SequenceMatcher(None, testtsatu[5], tesaja[5]).ratio()
            if judulcek>0.7:
                print(judulcek)
                print(testtsatu[5])
                print(SequenceMatcher(None, testtsatu[4], tesaja[4]).ratio())
# Out:
#    Wo....yo
#
# [INTRO]
#    C F G F (4x)
#
# Mari bareng magending,
# bareng Nanoe Biru,
# matan I Luh e mobil
#
# Woyoyoyo
#
# C         F              G          F         C
# Sabilang pesu ngajak I Luh, beli pasti cemburu
#               F            G             F       C
# Sabilang malali ngajak I Luh, tangkah beline kebus
#       F   G       F        C
# Matan I Luh e, muani mamobil
#       F   G                      C
# Ortan I Luh e, jeg suba pasti mobil
#
# [INTRO]
#    C F G F (2X)
# Woyoyoyoyooo
#
# C          F            G        F                  C
# Yen jani pesu ngajak I Luh, I Luh pasti ngorang sibuk
#                  F             G         F        C
# Sing baange pesu jak Bapan I Luh, keto alasan I Luh
#        F     G      F         C
# Hobin I Luh e, menegakin mobil
#    F     G      F               C
# I Luh nagih, majemput baan mobil
#
# [REFF]
#
#           G      F             C
# Matan I Luh e mobil Beli mara nawang
# F         G       F              G
# ...
