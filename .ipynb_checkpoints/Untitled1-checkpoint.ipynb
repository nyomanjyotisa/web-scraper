# %%
import csv
import pymysql

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="",
  database="chord"
)
cur_mydb = mydb.cursor()

with open('chord.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            artis = row[1]
            judul = row[2]
            chord = row[3]
            
            
            judul = judul.replace(artis + " ", "")
            
            print(artis)
            print(judul)
            
            query = "SELECT * FROM artis WHERE artis=%s"
            cur_mydb.execute(query, artis)
            row_count = cur_mydb.rowcount
            
            if row_count == 0:
                query = "INSERT INTO artis (artis) VALUES (%s)"
                cur_mydb.execute(query, artis)
                mydb.commit()
                
            query = "SELECT id FROM artis WHERE artis=%s"
            cur_mydb.execute(query, artis)
            artisid = cur_mydb.fetchone()
            
            print(artisid[0])
            
            
            lagu =(artisid[0], judul, chord)
            query = "INSERT INTO lagu (artis_id, judul, chord) VALUES (%s, %s, %s)"
            cur_mydb.execute(query, lagu)
            mydb.commit()
            
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are , artiss, juduls, chords
# Nanoe Biroe
# Matan Iluhe Mobil
# 1
# Ary Kencana
# Baper
# 2
# Kis Band
# Fullmoon
# 3
# Leeyonk Sinatra
# LDR (Lelah Dilanda Rindu)
# 4
# Harmonia
# Lagu Untukmu
# 5
# Nol Dp
# Putu Sintya Dewi
# 6
# Bintang Band
# Satya
# 7
# Motifora
# Hitam Putih
# 8
# Lolot
# Ulian Punyah
# 9
# Yoganata
# Ade Ne Kuang
# 10
# Nanoe Biroe
# Merasa Coklat
# 1
# 4WD
# Curahan Hati
# 11
# Lebri Partami
# Tresna Terlarang (Versi Akustik)
# 12
# Lebri Partami
# Sadar
# 12
# Kis Band
# Secret Lover
# 3
# Lolot
# Jegeg Bagus Bajang Bali
# 9
# 703 Band
# Kamu
# 13
# Harmonia
# Kekasih Sanubariku
# 5
# Oney Band
# De Munju Munju
# 14
# Lolot
# Pasawitran Bali Rockers
# 9
# D'Ubud Band
# Iluh Oh
# 15
# Kis Band
# Sabar
# 3
# Harmonia
# Sehidup Semati
# 5
# D'Ubud Band
# Gantung
# 15
# Kis Band
# Aku Mau Kamu
# 3
# Dek Ulik
# Tresna Ilang
# 16
# Lolot
# Galah Ngelahin Memitra
# 9
# D'Ubud Band
# Mekenyem Ja Adi
# 15
# XXX Band
# Anak Bali
# 17
# Kis Band
# Insting
# 3
# Nanoe Biroe
# Jantung Ati
# 1
# Margi
# Ubad Tatu
# 18
# XXX Band
# Sangut Delem
# 17
# Harmonia
# Menjauh Darimu
# 5
# Leeyonk Sinatra
# Kisahmu Ceritaku
# 4
# Nanoe Biroe
# Cewek Kafe Juga Manusia
# 1
# Rocktober
# Seharusne
# 19
# Bintang Band
# Bidadari
# 7
# Kis Band
# 2501
# 3
# XXX Band
# Puputan Badung
# 17
# Gus Dek Wijaya
# Buka Gegendong
# 20
# D'Ubud Band
# Bli Bangsat
# 15
# 4WD
# Persimpangan Hati
# 11
# BNSP
# Punyah
# 21
# Rocktober
# Tolong Jujur Ken Beli
# 19
# Bayu Cuaca
# Ngeling Sambil Manting
# 22
# Lolot
# Karman Beli
# 9
# Lolot
# Tembang Balu
# 9
# Lolot
# Nyujuh Langit
# 9
# Sunset Band
# Sing Ngidang Ngomong Ape
# 23
# Raja Band
# Iluh Aluh
# 24
# Lolot
# Swasti Wanti Warsa
# 9
# Lolot
# Beli Naskeleng
# 9
# Bintang Band
# Manis Manesin
# 7
# Mercy
# Api Cemburu
# 25
# Lolot
# Astungkara
# 9
# NorthSideBoys12
