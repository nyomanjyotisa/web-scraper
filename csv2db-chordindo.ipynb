# %%
import csv
import pymysql

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="",
  database="chord-gitar"
)
cur_mydb = mydb.cursor()

with open('chordindo-2.csv', errors="ignore") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:
        print(line_count)
        if line_count == 0:
            line_count += 1
        else:
            print(len(row))
            
            try:    
                artis = row[1].strip().split(' - ')[0]
                judul = row[2].strip().split(' - ')[1]
                chord = row[3].replace("Â","").replace("Â","").strip().split('Lihat Semua :')[0]

                judul = judul.replace(artis + " ", "")
                
                artis = artis.replace("Kunci Gitar ", "")

                print(artis)
                print(judul)
#                 print(chord)

                query = "SELECT * FROM artis WHERE artis=%s"
                cur_mydb.execute(query, artis)
                row_count = cur_mydb.rowcount
                
                query = "SELECT * FROM artis WHERE artis=%s"
                cur_mydb.execute(query, judul)
                row_count2 = cur_mydb.rowcount
                
                print('masuk')

                if row_count != 0:
                    print('masuk1')
                    query = "SELECT id FROM artis WHERE artis=%s"
                    cur_mydb.execute(query, artis)
                    artisid = cur_mydb.fetchone()
                    
                    cek_judul = (artisid[0], judul)
                    query = "SELECT * FROM lagu WHERE artis_id=%s && judul=%s"
                    cur_mydb.execute(query, cek_judul)
                    judul_check = cur_mydb.rowcount
                    
                    if judul_check == 0:
                        lagu =(artisid[0], judul, chord)
                        query = "INSERT INTO lagu (artis_id, judul, chord) VALUES (%s, %s, %s)"
                        cur_mydb.execute(query, lagu)
                        mydb.commit()
                        print("tes")
                    else:
                        print("apaya")

                elif row_count2 != 0:
                    print('masuk2')
                    query = "SELECT id FROM artis WHERE artis=%s"
                    cur_mydb.execute(query, judul)
                    artisid1 = cur_mydb.fetchone()
                    
                    cek_judul1 = (artisid1[0], artis)
                    query = "SELECT * FROM lagu WHERE artis_id=%s && judul=%s"
                    cur_mydb.execute(query, cek_judul1)
                    judul_check1 = cur_mydb.rowcount
                    
                    if judul_check1 == 0:
                        lagu =(artisid1[0], artis, chord)
                        query = "INSERT INTO lagu (artis_id, judul, chord) VALUES (%s, %s, %s)"
                        cur_mydb.execute(query, lagu)
                        mydb.commit()
                        print("tes")
                    else:
                        print("apaya")
                
                else :
                    print('masuk3')
                    judul_lagu = row[2].replace("Kunci Gitar ", "")
                    print(judul_lagu)
                    lagu2 =(877, judul_lagu, chord)
                    
                    query = "SELECT * FROM lagu WHERE judul=%s"
                    cur_mydb.execute(query, judul_lagu)
                    judul_check2 = cur_mydb.rowcount
                    
                    if judul_check2 == 0:
                        query = "INSERT INTO lagu (artis_id, judul, chord) VALUES (%s, %s, %s)"
                        cur_mydb.execute(query, lagu2)
                        mydb.commit()
                    else:
                        print("apaya")
                    
            except:
                print("yo")
            
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# 0
# 1
# 4
# Vicky Salamor
# Cinta Beda Agama
# masuk
# masuk1
# apaya
# 2
# 4
# Vicky Salamor
# Cinta Beda Agama
# masuk
# masuk1
# apaya
# 3
# 4
# Ilir7
# Sella Selli
# masuk
# masuk1
# apaya
# 4
# 4
# Dj Qhelfin
# Sory Banyak-Banyak
# masuk
# masuk1
# apaya
# 5
# 4
# Victor Hutabarat
# Sai Anju Ma Au
# masuk
# masuk3
# Victor Hutabarat - Sai Anju Ma Au
# apaya
# 6
# 4
# Aftershine
# Jomblo Bebas
# masuk
# masuk1
# apaya
# 7
# 4
# Corazon
# Nasibku
# masuk
# masuk1
# apaya
# 8
# 4
# Corazon
# Tresnoku Selawase
# masuk
# masuk1
# apaya
# 9
# 4
# Corazon
# Stress Pikir
# masuk
# masuk1
# apaya
# 10
# 4
# Corazon
# Janjine Ora Ono Nyatane
# masuk
# masuk1
# apaya
# 11
# 4
# Corazon
# Tresnoku Ra Bakal Ilang
# masuk
# masuk1
# apaya
# 12
# 4
# Vivziepop
# Oh Millie
# masuk
# masuk3
# Vivziepop - Oh Millie - Helluva Boss
# apaya
# 13
# 4
# Duc Phuc
# Hon Ca Yeu (HÆ N Cáº¢ YÃŠU
# masuk
# masuk3
# Duc Phuc - Hon Ca Yeu (HÆ N Cáº¢ YÃŠU - Äá»¨C PHÃšC)
# 14
# 4
# Dutkustik
# Ambarawa Ninggal Cerito
# masuk
# masuk1
# apaya
# 15
# 4
# David Iztambul
# Tangih Bapayuang Rumah
# masuk
# masuk1
# apaya
# 16
# 4
# Vita Alvia
# Dada Atau Paha
# masuk
# masuk1
# apaya
# 17
# 4
# Dara Ayu feat. Bajol Ndanu
# Izinkan
# masuk
# masuk3
# Dara Ayu feat. Bajol Ndanu - Izinkan
# apaya
# 18
# 4
# Arastra
# Sia-Sia
# masuk
# masuk3
# Arastra - Sia-Sia
# apaya
# 19
# 4
# Dygta
# Tersiksa Rindu (OST. Samudra Cinta)
# masuk
# masuk1
# apaya
# 20
# 4
# Happy Asmara
# Aku Ora Biasa
# masuk
# masuk1
# apaya
# Processed 21 lines.
