# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/b"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/b/b-a-p">B.A.P</a>
# B.A.P
# masuk
# <a href="https://www.chordindonesia.com/b/baby-monkey">Baby Monkey</a>
# Baby Monkey
# masuk
# <a href="https://www.chordindonesia.com/b/baby-sexyola">Baby Sexyola</a>
# Baby Sexyola
# masuk
# <a href="https://www.chordindonesia.com/b/baby-shima">Baby Shima</a>
# Baby Shima
# Tidak masuk
# <a href="https://www.chordindonesia.com/b/backstreet-boys">Backstreet Boys</a>
# Backstreet Boys
# masuk
# <a href="https://www.chordindonesia.com/b/badai-romantic-project">Badai Romantic Project</a>
# Badai Romantic Project
# Tidak masuk
# <a href="https://www.chordindonesia.com/b/baekhyun">Baekhyun</a>
# Baekhyun
# Tidak masuk
# <a href="https://www.chordindonesia.com/b/bagarap">Bagarap</a>
# Bagarap
# Tidak masuk
# <a href="https://www.chordindonesia.com/b/bagas-difa">Bagas Difa</a>
# Bagas Difa
# masuk
# <a href="https://www.chordindonesia.com/b/bagas-indi">Bagas Indi</a>
# Bagas Indi
# masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/c"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/c/caffeine">Caffeine</a>
# Caffeine
# Tidak masuk
# <a href="https://www.chordindonesia.com/c/cak-diqin">Cak Diqin</a>
# Cak Diqin
# Tidak masuk
# <a href="https://www.chordindonesia.com/c/cak-nun">Cak Nun</a>
# Cak Nun
# Tidak masuk
# <a href="https://www.chordindonesia.com/c/cak-percil">Cak Percil</a>
# Cak Percil
# Tidak masuk
# <a href="https://www.chordindonesia.com/c/cak-sodiq">Cak Sodiq</a>
# Cak Sodiq
# masuk
# <a href="https://www.chordindonesia.com/c/cake">Cake</a>
# Cake
# masuk
# <a href="https://www.chordindonesia.com/c/cakra-khan">Cakra Khan</a>
# Cakra Khan
# Tidak masuk
# <a href="https://www.chordindonesia.com/c/calum-scott">Calum Scott</a>
# Calum Scott
# Tidak masuk
# <a href="https://www.chordindonesia.com/c/calvin-harris">Calvin Harris</a>
# Calvin Harris
# masuk
# <a href="https://www.chordindonesia.com/c/calvin-jeremy">Calvin Jeremy</a>
# Calvin Jeremy
# Tidak masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/d"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/d/d-ari">D'Ari</a>
# D'Ari
# masuk
# <a href="https://www.chordindonesia.com/d/d-bagindas">D'Bagindas</a>
# D'Bagindas
# Tidak masuk
# <a href="https://www.chordindonesia.com/d/d-cinnamons">D'Cinnamons</a>
# D'Cinnamons
# Tidak masuk
# <a href="https://www.chordindonesia.com/d/d-clara">D'Clara</a>
# D'Clara
# masuk
# <a href="https://www.chordindonesia.com/d/d-cozt">D'Cozt</a>
# D'Cozt
# masuk
# <a href="https://www.chordindonesia.com/d/d-lapan">D'lapan</a>
# D'lapan
# masuk
# <a href="https://www.chordindonesia.com/d/d-lloyd">D’lloyd</a>
# D’lloyd
# masuk
# <a href="https://www.chordindonesia.com/d/d-masiv">D'Masiv</a>
# D'Masiv
# Tidak masuk
# <a href="https://www.chordindonesia.com/d/d-paspor">D'Paspor</a>
# D'Paspor
# Tidak masuk
# <a href="https://www.chordindonesia.com/d/d-try">D'Try</a>
# D'Try
# masuk
# <a href="https://www.chordindonesia.com/d/d-wapinz">D'Wapinz</a>
# D'Wapinz
# masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/e"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/e/early-summer">Early Summer</a>
# Early Summer
# masuk
# <a href="https://www.chordindonesia.com/e/east-nation">East Nation</a>
# East Nation
# masuk
# <a href="https://www.chordindonesia.com/e/ebet-kadarusman">Ebet Kadarusman</a>
# Ebet Kadarusman
# masuk
# <a href="https://www.chordindonesia.com/e/ebiet-g-ade">Ebiet G. Ade</a>
# Ebiet G. Ade
# Tidak masuk
# <a href="https://www.chordindonesia.com/e/ebo-zw">Ebo ZW</a>
# Ebo ZW
# masuk
# <a href="https://www.chordindonesia.com/e/ecca-mamamia">Ecca Mamamia</a>
# Ecca Mamamia
# masuk
# <a href="https://www.chordindonesia.com/e/ecca-noerma">Ecca Noerma</a>
# Ecca Noerma
# masuk
# <a href="https://www.chordindonesia.com/e/echa-virginia">Echa Virginia</a>
# Echa Virginia
# Tidak masuk
# <a href="https://www.chordindonesia.com/e/eclat">Eclat</a>
# Eclat
# Tidak masuk
# <a href="https://www.chordindonesia.com/e/ecoutez">Ecoutez</a>
# Ecoutez
# masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/f"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/f/f-d-m-for-dance-miracle">F.D.M (For Dance Miracle)</a>
# F.D.M (For Dance Miracle)
# Tidak masuk
# <a href="https://www.chordindonesia.com/f/f-t-island">F.T. Island</a>
# F.T. Island
# Tidak masuk
# <a href="https://www.chordindonesia.com/f/fa">FA</a>
# FA
# Tidak masuk
# <a href="https://www.chordindonesia.com/f/faby">Faby</a>
# Faby
# Tidak masuk
# <a href="https://www.chordindonesia.com/f/faby-marcelia">Faby Marcelia</a>
# Faby Marcelia
# Tidak masuk
# <a href="https://www.chordindonesia.com/f/fade-2-black">Fade 2 Black</a>
# Fade 2 Black
# Tidak masuk
# <a href="https://www.chordindonesia.com/f/fadli-habibi">Fadli Habibi</a>
# Fadli Habibi
# masuk
# <a href="https://www.chordindonesia.com/f/fadly">Fadly</a>
# Fadly
# Tidak masuk
# <a href="https://www.chordindonesia.com/f/fadly-padi">Fadly Padi</a>
# Fadly Padi
# masuk
# <a href="https://www.chordindonesia.com/f/fadly-rasul">Fadly Rasul</a>
# Fadly Rasul
# Tidak masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/g"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/g/g-eazy">G-Eazy</a>
# G-Eazy
# masuk
# <a href="https://www.chordindonesia.com/g/g-o-d">G.O.D</a>
# G.O.D
# masuk
# <a href="https://www.chordindonesia.com/g/gabe-wely">Gabe Wely</a>
# Gabe Wely
# masuk
# <a href="https://www.chordindonesia.com/g/gabetama-trio">Gabetama Trio</a>
# Gabetama Trio
# masuk
# <a href="https://www.chordindonesia.com/g/gabriela-bee">Gabriela Bee</a>
# Gabriela Bee
# Tidak masuk
# <a href="https://www.chordindonesia.com/g/gaby">Gaby</a>
# Gaby
# Tidak masuk
# <a href="https://www.chordindonesia.com/g/gading-feat-giselle">Gading feat Giselle</a>
# Gading feat Giselle
# masuk
# <a href="https://www.chordindonesia.com/g/gadiz">Gadiz</a>
# Gadiz
# masuk
# <a href="https://www.chordindonesia.com/g/gafar">Gafar</a>
# Gafar
# masuk
# <a href="https://www.chordindonesia.com/g/galang-gaviar">Galang Gaviar</a>
# Galang Gaviar
# Tidak masuk
# <a href="https://www.chordindonesia.com/g/galih-bangun">Galih Bangun</a>
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/h"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/h/ha-hyun-sang">Ha Hyun Sang</a>
# Ha Hyun Sang
# masuk
# <a href="https://www.chordindonesia.com/h/haddad-alwi">Haddad Alwi</a>
# Haddad Alwi
# Tidak masuk
# <a href="https://www.chordindonesia.com/h/hael-husaini">Hael Husaini</a>
# Hael Husaini
# Tidak masuk
# <a href="https://www.chordindonesia.com/h/hafid-ahkam">Hafid Ahkam</a>
# Hafid Ahkam
# masuk
# <a href="https://www.chordindonesia.com/h/hafiz">Hafiz</a>
# Hafiz
# Tidak masuk
# <a href="https://www.chordindonesia.com/h/hafiz-suip">Hafiz Suip</a>
# Hafiz Suip
# masuk
# <a href="https://www.chordindonesia.com/h/hailee-steinfeld">Hailee Steinfeld</a>
# Hailee Steinfeld
# masuk
# <a href="https://www.chordindonesia.com/h/hal">Hal</a>
# Hal
# masuk
# <a href="https://www.chordindonesia.com/h/halmahera">Halmahera</a>
# Halmahera
# masuk
# <a href="https://www.chordindonesia.com/h/halsey">Halsey</a>
# Halsey
# masuk
# <a href="https://www.chordindonesia.com/h/hamdan-att">Hamdan ATT</a>
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/i"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/i/i-o-i">I.O.I</a>
# I.O.I
# masuk
# <a href="https://www.chordindonesia.com/i/ian-kasela">Ian Kasela</a>
# Ian Kasela
# Tidak masuk
# <a href="https://www.chordindonesia.com/i/ian-surya">Ian Surya</a>
# Ian Surya
# masuk
# <a href="https://www.chordindonesia.com/i/ica-janesa">Ica Janesa</a>
# Ica Janesa
# Tidak masuk
# <a href="https://www.chordindonesia.com/i/ical-mandala">Ical Mandala</a>
# Ical Mandala
# masuk
# <a href="https://www.chordindonesia.com/i/iceu-wong">Iceu Wong</a>
# Iceu Wong
# masuk
# <a href="https://www.chordindonesia.com/i/icha-eviana">Icha Eviana</a>
# Icha Eviana
# masuk
# <a href="https://www.chordindonesia.com/i/icha-farera">Icha Farera</a>
# Icha Farera
# masuk
# <a href="https://www.chordindonesia.com/i/icha-olifa">Icha Olifa</a>
# Icha Olifa
# Tidak masuk
# <a href="https://www.chordindonesia.com/i/icha-zagita">Icha Zagita</a>
# Icha Zagita
# Tidak masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/j"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/j/j-rocks">J-Rocks</a>
# J-Rocks
# Tidak masuk
# <a href="https://www.chordindonesia.com/j/j-y-t-666">J.Y.T 666</a>
# J.Y.T 666
# masuk
# <a href="https://www.chordindonesia.com/j/ja-feat-tius">Ja feat Tius</a>
# Ja feat Tius
# masuk
# <a href="https://www.chordindonesia.com/j/jack-jack">Jack &amp; Jack</a>
# Jack & Jack
# masuk
# <a href="https://www.chordindonesia.com/j/jackson-wang">Jackson Wang</a>
# Jackson Wang
# Tidak masuk
# <a href="https://www.chordindonesia.com/j/jado">JADO</a>
# JADO
# masuk
# <a href="https://www.chordindonesia.com/j/jagostu">Jagostu</a>
# Jagostu
# masuk
# <a href="https://www.chordindonesia.com/j/jaja-miharja">Jaja Miharja</a>
# Jaja Miharja
# Tidak masuk
# <a href="https://www.chordindonesia.com/j/jaka-s">Jaka S</a>
# Jaka S
# Tidak masuk
# <a href="https://www.chordindonesia.com/j/jaluz">Jaluz</a>
# Jaluz
# Tidak masuk
# <a href="https://www.chordindonesia.com/j/jamal-minang">Jamal (Minang)</a>
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/k"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/k/k-391">K-391</a>
# K-391
# Tidak masuk
# <a href="https://www.chordindonesia.com/k/k-will">K.Will</a>
# K.Will
# masuk
# <a href="https://www.chordindonesia.com/k/kabel-data">Kabel Data</a>
# Kabel Data
# masuk
# <a href="https://www.chordindonesia.com/k/kacha-band">Kacha Band</a>
# Kacha Band
# masuk
# <a href="https://www.chordindonesia.com/k/kadal-band">Kadal Band</a>
# Kadal Band
# masuk
# <a href="https://www.chordindonesia.com/k/kahitna">Kahitna</a>
# Kahitna
# Tidak masuk
# <a href="https://www.chordindonesia.com/k/kaini-sura">Kaini Sura</a>
# Kaini Sura
# masuk
# <a href="https://www.chordindonesia.com/k/kaka-azraff">Kaka Azraff</a>
# Kaka Azraff
# Tidak masuk
# <a href="https://www.chordindonesia.com/k/kakung-lintang">Kakung Lintang</a>
# Kakung Lintang
# masuk
# <a href="https://www.chordindonesia.com/k/kalia-siska">Kalia Siska</a>
# Kalia Siska
# Tidak masuk
# <a href="https://www.chordindonesia.com/k/kamar-jiwa">Kamar Jiwa</a>
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/l"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/l/l-arc-en-ciel">L'Arc En Ciel</a>
# L'Arc En Ciel
# Tidak masuk
# <a href="https://www.chordindonesia.com/l/l-o-band">L.O Band</a>
# L.O Band
# masuk
# <a href="https://www.chordindonesia.com/l/l-ramli">L. Ramli</a>
# L. Ramli
# masuk
# <a href="https://www.chordindonesia.com/l/la-luna">La Luna</a>
# La Luna
# masuk
# <a href="https://www.chordindonesia.com/l/lacy-band">Lacy Band</a>
# Lacy Band
# Tidak masuk
# <a href="https://www.chordindonesia.com/l/lady-gaga">Lady Gaga</a>
# Lady Gaga
# Tidak masuk
# <a href="https://www.chordindonesia.com/l/ladys-ska">Lady's SKA</a>
# Lady's SKA
# masuk
# <a href="https://www.chordindonesia.com/l/lafrosia">Lafrosia</a>
# Lafrosia
# masuk
# <a href="https://www.chordindonesia.com/l/lagu-anak">Lagu Anak</a>
# Lagu Anak
# Tidak masuk
# <a href="https://www.chordindonesia.com/l/lagu-nasional">Lagu Nasional</a>
# Lagu Nasional
# masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/m"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/m/m-a-c">M.A.C</a>
# M.A.C
# masuk
# <a href="https://www.chordindonesia.com/m/m-fajar-sodiq">M. Fajar Sodiq</a>
# M. Fajar Sodiq
# masuk
# <a href="https://www.chordindonesia.com/m/m-ridlwan">M. Ridlwan</a>
# M. Ridlwan
# masuk
# <a href="https://www.chordindonesia.com/m/m2m">M2M</a>
# M2M
# Tidak masuk
# <a href="https://www.chordindonesia.com/m/mace-purba">Mace Purba</a>
# Mace Purba
# masuk
# <a href="https://www.chordindonesia.com/m/machine-gun-kelly">Machine Gun Kelly</a>
# Machine Gun Kelly
# Tidak masuk
# <a href="https://www.chordindonesia.com/m/mad-clown">Mad Clown</a>
# Mad Clown
# masuk
# <a href="https://www.chordindonesia.com/m/madam">Madam</a>
# Madam
# Tidak masuk
# <a href="https://www.chordindonesia.com/m/madesya-group">Madesya Group</a>
# Madesya Group
# masuk
# <a href="https://www.chordindonesia.com/m/maell-lee">Maell Lee</a>
# Maell Lee
# Tidak masuk
# <a href="https://www.chordindonesia.com/m/magic">Magic!</a>
# Magic!
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/n"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/n/nabasa-trio">Nabasa Trio</a>
# Nabasa Trio
# Tidak masuk
# <a href="https://www.chordindonesia.com/n/nabila">Nabila</a>
# Nabila
# Tidak masuk
# <a href="https://www.chordindonesia.com/n/nabila-cahya">Nabila Cahya</a>
# Nabila Cahya
# Tidak masuk
# <a href="https://www.chordindonesia.com/n/nabila-lida">Nabila LIDA</a>
# Nabila LIDA
# masuk
# <a href="https://www.chordindonesia.com/n/nabila-maharani">Nabila Maharani</a>
# Nabila Maharani
# Tidak masuk
# <a href="https://www.chordindonesia.com/n/nabila-moure">Nabila Moure</a>
# Nabila Moure
# masuk
# <a href="https://www.chordindonesia.com/n/nabila-yuza">Nabila Yuza</a>
# Nabila Yuza
# masuk
# <a href="https://www.chordindonesia.com/n/nabilla-yuza">Nabilla Yuza</a>
# Nabilla Yuza
# Tidak masuk
# <a href="https://www.chordindonesia.com/n/nada-cinta-band">Nada Cinta Band</a>
# Nada Cinta Band
# masuk
# <a href="https://www.chordindonesia.com/n/nada-kentjana">Nada Kentjana</a>
# Nada Kentjana
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/o"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/o/oasis">Oasis</a>
# Oasis
# Tidak masuk
# <a href="https://www.chordindonesia.com/o/obbie-messakh">Obbie Messakh</a>
# Obbie Messakh
# Tidak masuk
# <a href="https://www.chordindonesia.com/o/ocan-siagian">Ocan Siagian</a>
# Ocan Siagian
# Tidak masuk
# <a href="https://www.chordindonesia.com/o/oday-akhras">Oday Akhras</a>
# Oday Akhras
# masuk
# <a href="https://www.chordindonesia.com/o/okin">Okin</a>
# Okin
# masuk
# <a href="https://www.chordindonesia.com/o/ola-cristine">Ola Cristine</a>
# Ola Cristine
# masuk
# <a href="https://www.chordindonesia.com/o/oliv">Oliv</a>
# Oliv
# masuk
# <a href="https://www.chordindonesia.com/o/om-kora">OM KORA</a>
# OM KORA
# Tidak masuk
# <a href="https://www.chordindonesia.com/o/om-putra">Om Putra</a>
# Om Putra
# masuk
# <a href="https://www.chordindonesia.com/o/om-syalala">Om Syalala</a>
# Om Syalala
# masuk
# <a href="https://www.chordindonesia.com/o/om-wawes">OM Wawes</a>
# OM Wawes
# Tidak masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/p"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/p/padi">Padi</a>
# Padi
# Tidak masuk
# <a href="https://www.chordindonesia.com/p/pagi-nan-cerah">Pagi Nan Cerah</a>
# Pagi Nan Cerah
# masuk
# <a href="https://www.chordindonesia.com/p/paidjo-band">Paidjo Band</a>
# Paidjo Band
# masuk
# <a href="https://www.chordindonesia.com/p/pakle">Pakle</a>
# Pakle
# Tidak masuk
# <a href="https://www.chordindonesia.com/p/pal-khan">Pal Khan</a>
# Pal Khan
# masuk
# <a href="https://www.chordindonesia.com/p/palak-muchhal">Palak Muchhal</a>
# Palak Muchhal
# masuk
# <a href="https://www.chordindonesia.com/p/pamungkas">Pamungkas</a>
# Pamungkas
# Tidak masuk
# <a href="https://www.chordindonesia.com/p/panbers">Panbers</a>
# Panbers
# Tidak masuk
# <a href="https://www.chordindonesia.com/p/pance-pondaag">Pance Pondaag</a>
# Pance Pondaag
# Tidak masuk
# <a href="https://www.chordindonesia.com/p/pangjek">Pangjek</a>
# Pangjek
# Tidak masuk
# <a href="https://www.chordindonesia.com/p/papacello">Papacello</a>
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/q"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/q/qasima">Qasima</a>
# Qasima
# Tidak masuk
# <a href="https://www.chordindonesia.com/q/qeisya-nahla">Qeisya Nahla</a>
# Qeisya Nahla
# masuk
# <a href="https://www.chordindonesia.com/q/qiff">Qiff</a>
# Qiff
# Tidak masuk
# <a href="https://www.chordindonesia.com/q/qonita">Qonita</a>
# Qonita
# masuk
# <a href="https://www.chordindonesia.com/q/qta">Qta</a>
# Qta
# masuk
# <a href="https://www.chordindonesia.com/q/quavo">Quavo</a>
# Quavo
# masuk
# <a href="https://www.chordindonesia.com/q/queen">Queen</a>
# Queen
# Tidak masuk

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/r"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/r/r-angkotasan">R. Angkotasan</a>
# R. Angkotasan
# masuk
# <a href="https://www.chordindonesia.com/r/rachma-anggara">Rachma Anggara</a>
# Rachma Anggara
# masuk
# <a href="https://www.chordindonesia.com/r/rachmat-kartolo">Rachmat Kartolo</a>
# Rachmat Kartolo
# Tidak masuk
# <a href="https://www.chordindonesia.com/r/rachmi-ayu">Rachmi Ayu</a>
# Rachmi Ayu
# Tidak masuk
# <a href="https://www.chordindonesia.com/r/raden-syair-langit">Raden Syair Langit</a>
# Raden Syair Langit
# masuk
# <a href="https://www.chordindonesia.com/r/radenriski-hoolahoop">Radenriski (Hoolahoop)</a>
# Radenriski (Hoolahoop)
# masuk
# <a href="https://www.chordindonesia.com/r/radiohead">Radiohead</a>
# Radiohead
# Tidak masuk
# <a href="https://www.chordindonesia.com/r/radiostar">Radiostar</a>
# Radiostar
# masuk
# <a href="https://www.chordindonesia.com/r/radja">Radja</a>
# Radja
# Tidak masuk
# <a href="https://www.chordindonesia.com/r/raef">Raef</a>
# Raef
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/s"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/s/s-k-o-k">S.K.O.K</a>
# S.K.O.K
# Tidak masuk
# <a href="https://www.chordindonesia.com/s/s-o-b">S.O.B</a>
# S.O.B
# masuk
# <a href="https://www.chordindonesia.com/s/s-o-s">S.O.S</a>
# S.O.S
# masuk
# <a href="https://www.chordindonesia.com/s/s-sham-orkes-teruna-ria">S.Sham &amp; Orkes Teruna Ria</a>
# S.Sham & Orkes Teruna Ria
# masuk
# <a href="https://www.chordindonesia.com/s/s9-x">S9-X</a>
# S9-X
# masuk
# <a href="https://www.chordindonesia.com/s/saba">Saba</a>
# Saba
# masuk
# <a href="https://www.chordindonesia.com/s/sabila">Sabila</a>
# Sabila
# masuk
# <a href="https://www.chordindonesia.com/s/sabrina-carpenter">Sabrina Carpenter</a>
# Sabrina Carpenter
# Tidak masuk
# <a href="https://www.chordindonesia.com/s/sabumi-band">Sabumi Band</a>
# Sabumi Band
# masuk
# <a href="https://www.chordindonesia.com/s/sabyan">Sabyan</a>
# Sabyan
# Tidak masuk
# <a href="https://www.chordindonesia.com/s/sadie-ladya">Sadie Ladya</a>
# Sadie Ladya
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/t"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/t/t-cash">T-Cash</a>
# T-Cash
# masuk
# <a href="https://www.chordindonesia.com/t/t-hijau">T-Hijau</a>
# T-Hijau
# masuk
# <a href="https://www.chordindonesia.com/t/t2">T2</a>
# T2
# Tidak masuk
# <a href="https://www.chordindonesia.com/t/taeil">Taeil</a>
# Taeil
# masuk
# <a href="https://www.chordindonesia.com/t/taemin-shinee">Taemin (SHINee)</a>
# Taemin (SHINee)
# masuk
# <a href="https://www.chordindonesia.com/t/taeyeon">Taeyeon</a>
# Taeyeon
# masuk
# <a href="https://www.chordindonesia.com/t/tagor-pangaribuan">Tagor Pangaribuan</a>
# Tagor Pangaribuan
# Tidak masuk
# <a href="https://www.chordindonesia.com/t/tahta">Tahta</a>
# Tahta
# Tidak masuk
# <a href="https://www.chordindonesia.com/t/tajul">Tajul</a>
# Tajul
# Tidak masuk
# <a href="https://www.chordindonesia.com/t/talitha-thyona-agatha">Talitha Thyona Agatha</a>
# Talitha Thyona Agatha
# masuk
# <a href="https://www.chordindonesia.com/t/tami-aulia">Tami Aulia</a>
# Tami Aulia
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/u"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/u/u-ks-ukays">Ukays</a>
# Ukays
# Tidak masuk
# <a href="https://www.chordindonesia.com/u/ubay-nidji">Ubay (Nidji)</a>
# Ubay (Nidji)
# masuk
# <a href="https://www.chordindonesia.com/u/ucie-sucita">Ucie Sucita</a>
# Ucie Sucita
# Tidak masuk
# <a href="https://www.chordindonesia.com/u/ucup-klaten">Ucup Klaten</a>
# Ucup Klaten
# Tidak masuk
# <a href="https://www.chordindonesia.com/u/udhin-leaders">Udhin Leaders</a>
# Udhin Leaders
# masuk
# <a href="https://www.chordindonesia.com/u/udin">Udin</a>
# Udin
# masuk
# <a href="https://www.chordindonesia.com/u/ulan">Ulan</a>
# Ulan
# masuk
# <a href="https://www.chordindonesia.com/u/ulil">Ulil</a>
# Ulil
# masuk
# <a href="https://www.chordindonesia.com/u/ully-moch">Ully Moch</a>
# Ully Moch
# Tidak masuk
# <a href="https://www.chordindonesia.com/u/un1ty">UN1TY</a>
# UN1TY
# Tidak masuk
# <a href="https://www.chordindonesia.com/u/uncle-djink">Uncle Djink</a>
# Uncle Djink
# Tidak masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/v"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/v/v-bts">V (BTS)</a>
# V (BTS)
# masuk
# <a href="https://www.chordindonesia.com/v/vadilla-sukma">Vadilla Sukma</a>
# Vadilla Sukma
# Tidak masuk
# <a href="https://www.chordindonesia.com/v/vagetoz">Vagetoz</a>
# Vagetoz
# Tidak masuk
# <a href="https://www.chordindonesia.com/v/valerie-pola">Valerie Pola</a>
# Valerie Pola
# Tidak masuk
# <a href="https://www.chordindonesia.com/v/vandella">Vandella</a>
# Vandella
# Tidak masuk
# <a href="https://www.chordindonesia.com/v/vanessa-angel">Vanessa Angel</a>
# Vanessa Angel
# Tidak masuk
# <a href="https://www.chordindonesia.com/v/vani-vania">Vani Vania</a>
# Vani Vania
# Tidak masuk
# <a href="https://www.chordindonesia.com/v/vania-larissa">Vania Larissa</a>
# Vania Larissa
# masuk
# <a href="https://www.chordindonesia.com/v/vanny-vabiola">Vanny Vabiola</a>
# Vanny Vabiola
# Tidak masuk
# <a href="https://www.chordindonesia.com/v/vany-thursdila">Vany Thursdila</a>
# Vany Thursdila
# Tidak masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/w"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/w/wafda-lubis">Wafda Lubis</a>
# Wafda Lubis
# Tidak masuk
# <a href="https://www.chordindonesia.com/w/wafi-singsing">Wafi Singsing</a>
# Wafi Singsing
# Tidak masuk
# <a href="https://www.chordindonesia.com/w/wafiq-azizah">Wafiq Azizah</a>
# Wafiq Azizah
# Tidak masuk
# <a href="https://www.chordindonesia.com/w/wagu-lagu">Wagu Lagu</a>
# Wagu Lagu
# Tidak masuk
# <a href="https://www.chordindonesia.com/w/wahyu">Wahyu</a>
# Wahyu
# Tidak masuk
# <a href="https://www.chordindonesia.com/w/wahyu-bs">Wahyu Bs</a>
# Wahyu Bs
# masuk
# <a href="https://www.chordindonesia.com/w/wali">Wali</a>
# Wali
# Tidak masuk
# <a href="https://www.chordindonesia.com/w/walk-the-moon">Walk The Moon</a>
# Walk The Moon
# masuk
# <a href="https://www.chordindonesia.com/w/wan-azlyn">Wan Azlyn</a>
# Wan Azlyn
# masuk
# <a href="https://www.chordindonesia.com/w/wan-parau">Wan Parau</a>
# Wan Parau
# Tidak masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/x"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/x/x-it">X-IT</a>
# X-IT
# masuk
# <a href="https://www.chordindonesia.com/x/xaluna">Xaluna</a>
# Xaluna
# Tidak masuk
# <a href="https://www.chordindonesia.com/x/xena-xenita">Xena Xenita</a>
# Xena Xenita
# masuk
# <a href="https://www.chordindonesia.com/x/xo-ix">XO-IX</a>
# XO-IX
# masuk
# <a href="https://www.chordindonesia.com/x/xxditto">XXDITTO</a>
# XXDITTO
# Tidak masuk

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/y"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/y/yan-vellia">Yan Vellia</a>
# Yan Vellia
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yanda-bebeh">Yanda Bebeh</a>
# Yanda Bebeh
# masuk
# <a href="https://www.chordindonesia.com/y/yangseku">Yangseku</a>
# Yangseku
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yank-mulia">Yank Mulia</a>
# Yank Mulia
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yarra">Yarra</a>
# Yarra
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yasmine-alena">Yasmine Alena</a>
# Yasmine Alena
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yayan-jatnika">Yayan Jatnika</a>
# Yayan Jatnika
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yazid-izaham">Yazid Izaham</a>
# Yazid Izaham
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yellow-claw">Yellow Claw</a>
# Yellow Claw
# Tidak masuk
# <a href="https://www.chordindonesia.com/y/yellowcard">Yellowcard</a>
# Yellowcard
# masuk
# ...

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import csv
import pymysql
from slugify import slugify

mydb = pymysql.connect(
  host="seratusbali.xyz",
  user="sern2389_manjyo",
  password="jyodb123",
  database="sern2389_rumahchord"
)
# mydb = pymysql.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="sern2389_chord-gitar"
# )
cur_mydb = mydb.cursor()

html = []
artis_html = []
post_html =[]


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www.chordindonesia.com/z"
req = Request(url=reg_url, headers=headers) 

html.append(urlopen(req).read())

soup = BeautifulSoup(html[0], "lxml")

page = soup.find('div', {'class': 'entry-content'})
pages = page.find_all('a', href=True)

for x in pages:
    print(x)
    nama_artis = x.get_text();
    print(nama_artis)
    query = "SELECT * FROM wp_terms WHERE name=%s"
    cur_mydb.execute(query, nama_artis)
    row_count = cur_mydb.rowcount

    if row_count == 0:
        print("masuk")
        slug_artis = slugify(nama_artis)
        artiss = (nama_artis, slug_artis)
        query = "INSERT INTO wp_terms (`name`, `slug`, `term_group`) VALUES (%s,%s, '0')"
        cur_mydb.execute(query, artiss)
        mydb.commit()

#         query = "INSERT INTO wp_term_taxonomy (`term_id`, `taxonomy`, `description`) VALUES (%s,'category', '')"
#         cur_mydb.execute(query, data_artis[0])
#         mydb.commit()
    else:
        print("Tidak masuk")
# Out:
# <a href="https://www.chordindonesia.com/z/zack-tabudlo">Zack Tabudlo</a>
# Zack Tabudlo
# masuk
# <a href="https://www.chordindonesia.com/z/zaenal-group">Zaenal Group</a>
# Zaenal Group
# masuk
# <a href="https://www.chordindonesia.com/z/zahra">Zahra</a>
# Zahra
# masuk
# <a href="https://www.chordindonesia.com/z/zahwa">Zahwa</a>
# Zahwa
# Tidak masuk
# <a href="https://www.chordindonesia.com/z/zali-rusli">Zali Rusli</a>
# Zali Rusli
# Tidak masuk
# <a href="https://www.chordindonesia.com/z/zara-larsson">Zara Larsson</a>
# Zara Larsson
# Tidak masuk
# <a href="https://www.chordindonesia.com/z/zara-leola">Zara Leola</a>
# Zara Leola
# Tidak masuk
# <a href="https://www.chordindonesia.com/z/zaskia-gotik">Zaskia Gotik</a>
# Zaskia Gotik
# Tidak masuk
# <a href="https://www.chordindonesia.com/z/zayn">Zayn</a>
# Zayn
# masuk
# <a href="https://www.chordindonesia.com/z/zecurity">Zecurity</a>
# Zecurity
# Tidak masuk
# <a href="https://www.chordindonesia.com/z/zedd">Zedd</a>
# Zedd
# masuk
# ...
