# %%
from urllib.request import urlopen

html = urlopen("http://chordlagubali.blogspot.com/2011/11/nanoe-biroe-anak-kost.html").read()
print(html)

# from urllib.request import urlopen

# html = []

# html.append(urlopen("http://chordlagubali.blogspot.com/2011/11/nanoe-biroe-anak-kost.html").read())
# print(html)
# Out:
# b'<!DOCTYPE html>\n<HTML lang="id-ID">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1" />\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<title>Kunci Gitar Armada - Drama Chord Dasar \xc2\xa9ChordTela.com</title><style id="rocket-critical-css">:root[color-mode=dark] .color-mode .dark--hidden{display:none}.color-mode__btn{padding:5px;margin:0;font-family:var(--sans);font-size:1rem;font-weight:600;line-height:1;color:#111;color:var(--element1,#111111);background:0 0;border:none}.color-mode__btn svg{width:15px;height:15px;fill:none;stroke:#fff;stroke:var(--element2,#ffffff);stroke-linecap:round;stroke-linejoin:round;stroke-width:1.5px}body{background:#000;color:#444;height:100%;font-family:Arial,Helvetica,Tahoma,sans-serif;font-size:14px;font-weight:400;line-height:22px;text-decoration:none;margin:0;padding:0}a,a:link{color:#0c0;text-decoration:none;fo
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "lxml")
print(type(soup))
print(soup.prettify()[1:1000])
    
# from bs4 import BeautifulSoup

# soup = BeautifulSoup(html[0], "lxml")

# x = len(html)
# i = 1

# while (i<x):
#     soup.append(BeautifulSoup(html[i], "lxml"))
#     print(type(soup))
#     print(soup.prettify()[1:1000])
#     i += 1
# Out:
# <class 'bs4.BeautifulSoup'>
# !DOCTYPE html>
# <html lang="id-ID">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <title>
#    Kunci Gitar Armada - Drama Chord Dasar ©ChordTela.com
#   </title>
#   <style id="rocket-critical-css">
# ...

# %%
produk = soup.find_all("div","post")

for p in produk:
    print(p.select_one(".post-title.entry-title").get_text())
    print(p.select_one(".post-title.entry-title").get_text())
    print(p.select_one('.post-body.entry-content pre').get_text())

# produk = soup.find_all("article","post")

# for p in produk:
#     print(p.select_one(".cat-links a").get_text())
#     print(p.select_one(".entry-header h2").get_text())
#     print(p.find('pre').get_text())
# Out:
# Kunci Gitar Armada - Drama
# Kunci Gitar Armada - Drama
# Intro: F..G..C..
#        F..G..C..
#
# C
# Awal kita bertemu
#  Em
# kamu mendekatiku
#    F              F  (-Em)
# ku anggap biasa saja..
#     Dm
# kau tawarkan cinta
#                   G
# seolah hanya untukku..
#
# *)
# C
# Kini aku terjebak
#    Em
# di balik sebuah rencana
#    F               F  (-Em)
# untuk mempermainkanku
#     Dm
# kau tinggikan aku
#                    G
# lalu kau jatuhkan aku..
#
# Reff I:
#             Am              C
#   Kau memainkan.. sebuah drama..
#                  Am
#   yang membuat diriku
#         G           Dm
#   bertekuk lutut di depanmu
#   -G        Am              C
#   kau memainkan..sebuah cerita..
#                  Am
#   yang membuat diriku
#          G      F
#   jatuh hati padamu..
#     Fm             G   C..
#   lalu kau tinggalkan aku..
#
# *)
# C
# Kini aku terjebak
#    Em
# di balik sebuah rencana
#    F               F  (-Em)
# untuk mempermainkanku
#     Dm
# ...

# %%
import pandas as pd

artis = []
judul = []
chord = []
i=1
produk = soup.find_all("div","post")

for p in produk:
    print(i)
    i += 1
    try:    
        artis.append(p.select_one(".post-title.entry-title").get_text())
    except:
        artis.append("zonk")
    try:    
        judul.append(p.select_one(".post-title.entry-title").get_text())
    except:
        judul.append("zonk")
    try:    
        chord.append(p.select_one('.post-body.entry-content').get_text().replace("Tweet","").replace("Author : Wayun Nempan","").replace("Author : Wayun Nempan","").replace("Credit","").replace("http://bliyanbelog.blogspot.com","").replace("Posted by Ngurah Adis",""))
    except:
        chord.append("zonk")
    
    
        

produk_dict = {'artiss':artis,'juduls':judul,'chords':chord}
df = pd.DataFrame(produk_dict)

df.sort_values('juduls',ascending=True)

# import pandas as pd

# artis = []
# judul = []
# chord = []
# i=1
# produk = soup.find_all("article","post")

# for p in produk:
#     print(i)
#     i += 1
#     artis.append(p.select_one(".cat-links a").get_text())
#     judul.append(p.select_one(".entry-header h2").get_text())
#     try:    
#         chord.append(p.find('pre').get_text())
#     except:
#         chord.append("zonk")
    

# produk_dict = {'artiss':artis,'juduls':judul,'chords':chord}
# df = pd.DataFrame(produk_dict)

# df.sort_values('juduls',ascending=True)
# Out:
# 1
#                        artiss                      juduls  \
# 0  Kunci Gitar Armada - Drama  Kunci Gitar Armada - Drama
#
#                                               chords
# 0  \nTranspose:Auto Scroll Light Mode    Dark Mod...

# %%
df.to_csv("tes1.csv", sep=',')

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup


html = []
i = 1

html = urlopen("http://chordlagubali.blogspot.com/2021/01/chord-budi-arsa-meme.html").read()

soup = BeautifulSoup(html[0], "lxml")

while (1):
    pages = soup.find('div', {'class': 'blog-pager'})
    print(pages)
    if not pages.find('div', {'id': 'blog-pager-older-link'}):
        url = str(pages.find(find('a')['href'])
    
    html.append(urlopen(url).read())
    soup = BeautifulSoup(html[i], "lxml")
    i += 1
    
    print(html)
# Out:
#   File "<ipython-input-30-e84abf6e57f5>", line 18
#     html.append(urlopen(url).read())
#     ^
# SyntaxError: invalid syntax
